# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonjavier1/Prompt-Engineering1/blob/main/QUESTION_1_Prompt_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Function to simulate checking an order in the database
def check_order_status(order_number):
    # Simulate an order if it doesn't exist
    shipped_date = "2026-02-" + str(random.randint(20, 28))
    estimated_delivery = "2026-03-" + str(random.randint(1, 5))
    tracking_number = "FSX" + str(random.randint(100000000, 999999999))
    carrier = "FastShip Express"
    status = random.choice(["Processing", "Shipped", "In Transit"])

    print(f"\nOrder #{order_number} Status:")
    print(f"  Status: {status}")
    print(f"  Shipped Date: {shipped_date}")
    print(f"  Estimated Delivery: {estimated_delivery}")
    print(f"  Carrier: {carrier}")
    print(f"  Tracking Number: {tracking_number}")
    print(f"  Tracking Link: https://www.fastship.com/track/{tracking_number}")
    return True

def subscribe_updates(order_number):
    print(f"\nYou are now subscribed to updates for order #{order_number}.")
    print("Simulating delivery updates...\n")

    updates = [
        "Package left the sorting facility.",
        "Package is out for delivery.",
        "Package delivered!"
    ]

    # Print updates instantly for Colab
    for update in updates:
        print(f"Update: {update}")

def main():
    print("Welcome to BrightCart Customer Support AI!")
    order_number = input("Please enter your order number: ").strip()

    if check_order_status(order_number):
        subscribe = input("\nWould you like to receive delivery updates? (yes/no): ").strip().lower()
        if subscribe == "yes":
            subscribe_updates(order_number)
        else:
            print("No updates subscribed. Thank you!")

if __name__ == "__main__":
    main()
# Out:
# Welcome to BrightCart Customer Support AI!
